# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a4b3aba54c8a> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/My Drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#      97
#      98   if ' ' in mountpoint:
# ---> 99     raise ValueError('Mountpoint must not contain a space.')
#     100
#     101   mountpoint = _os.path.expanduser(mountpoint)
#
# ValueError: Mountpoint must not contain a space.

# %%
/content/drive/My Drive/spread_GAN

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 2337 (delta 0), reused 0 (delta 0), pack-reused 2334
# Receiving objects: 100% (2337/2337), 8.09 MiB | 35.42 MiB/s, done.
# Resolving deltas: 100% (1498/1498), done.

# %%
import os
os.chdir('/content/pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 6.6MB/s
# ...
#      |████████████████████████████████| 204kB 18.2MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=65c56281d7a6344dbd95d11d79b65de7bee95cd859be43cd223204c73ee704a5
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=e2c8e9aceef31bf0056820557f5da4cc15e2d25a97cb9d2502c8ffc3936a8dda
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
# #move files 
# import os
# import shutil
# num = 1

# for file in os.listdir("/content/drive/My Drive/spread_GAN/trainB"):
#     if file.endswith(".jpg") and num<=1:
#         print(os.path.join("/content/drive/My Drive/spread_GAN/testB", file))
#         new = shutil.move(os.path.join("/content/drive/My Drive/spread_GAN/trainB",file), os.path.join("/content/drive/My Drive/spread_GAN/testB/",file) ) #WRONG
#         num += 1

# %%
# !python3 train.py --dataroot '/content/drive/My Drive/spread_GAN' --name horsetozebra --model cycle_gan --checkpoints_dir '/content/drive/My Drive/spread_GAN/checkpoints'
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/My Drive/spread_GAN/checkpoints	[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/drive/My Drive/spread_GAN	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
# ...
